# %%
import sys
sys.path.append('../')
from core import LADTransferTreeBoost, LSTransferTreeBoost, MTransferTreeBoost
import pandas as pd
from sklearn.model_selection import train_test_split
import numpy as np
from utils import *  #only needed for xgboost
import xgboost as xgb
from baselines import *

# %%
predictor_columns = [str(i) for i in range(3, 26)]
target_column = 'estimated_volume'

# %%
data = pd.read_csv('datasets/stem_data.csv', index_col = [0])
#split according to species
data_source = data[data['Species'] == 'Pine']
data_target = data[data['Species'] == 'Spruce']

# #split according to latitude
# q3 = np.percentile(data.copy()['Lat'], 25)
# data_source = data[data['Lat'] >= q3]
# data_target = data[data['Lat'] < q3]

#change source label from volume to height
print(f'source dataset size: {len(data_source)}, target dataset size: {len(data_target)}')

data_train, data_test = train_test_split(data_target, test_size=0.1, random_state=34)

print(f'train (target) dataset size: {len(data_train)}, test (target) dataset size: {len(data_test)}')
# Out:
# source dataset size: 197, target dataset size: 113
# train (target) dataset size: 101, test (target) dataset size: 12

# %%
X_source_train = np.array(data_source[predictor_columns])
y_source_train = np.array(data_source['Height'])

#Specific train and test set
X_target_train = np.array(data_train[predictor_columns])
y_target_train = np.array(data_train[target_column])

X_target_test = np.array(data_test[predictor_columns])
y_target_test = np.array(data_test[target_column])

# %%
fiter = LSTransferTreeBoost(epochs=150, target_tree_size=2, k = 0.0, m_0 = 0.5)
fiter.fit(X_target_train, y_target_train, X_source_train, y_source_train, show_curves = True)
rmse = fiter.evaluate(X_target_test, y_target_test, metric = 'rmse')
mae = fiter.evaluate(X_target_test, y_target_test, metric = 'mae')

print((rmse / np.mean(y_target_test))*100)
# Out:
# 12.568588998174837

# %%
from sklearn.ensemble import GradientBoostingRegressor

reg = GradientBoostingRegressor(random_state=0, validation_fraction=0.1, n_estimators=500, n_iter_no_change=5, loss='huber', max_depth=3)
reg.fit(X_target_train, y_target_train)
preds = reg.predict(X_target_test)
rmse = compute_rmse(preds, y_target_test)
mae = compute_mae(preds, y_target_test)

print((rmse / np.mean(y_target_test))*100)

reg.n_estimators_
# Out:
# 13.283613521748586
# 50

# %%
params = {
    'objective': 'reg:squarederror',  # Regression with squared error
    'max_depth': 2,                   # Maximum depth of a tree
    'eta': 0.1,                       # Learning rate
    'eval_metric': 'rmse',           # RMSE as evaluation metric
    }
        
bst = train_xgboost(X_target_train, y_target_train, X_target_train, y_target_train, boosting_rounds=150, params=params, early_stopping_rounds=500, show_curve=True)
preds = test_xgboost(X_target_test, bst)
rmse = compute_rmse(preds, y_target_test)
mae = compute_mae(preds, y_target_test)

print((rmse / np.mean(y_target_test))*100)
# Out:
# 15.477503104665852

# %%
import warnings
warnings.filterwarnings('ignore')
from adapt.instance_based import TrAdaBoostR2, TwoStageTrAdaBoostR2
from sklearn.metrics import mean_squared_error, mean_absolute_error
from m5py import M5Prime

from lineartree import LinearTreeRegressor
from sklearn.linear_model import LinearRegression

base_estimator = M5Prime()
model = TrAdaBoostR2(base_estimator,
                        n_estimators=30,
                        lr=1)
model.fit(X_source_train, y_source_train,
            X_target_train, y_target_train)
preds = model.predict(X_target_test)
rmse = np.sqrt(mean_squared_error(
    preds, y_target_test))
mae = mean_absolute_error(preds, y_target_test)
print((rmse / np.mean(y_target_test))*100)
# Out:
# Iteration 0 - Error: 0.2762
# Iteration 1 - Error: 0.3780
# Iteration 2 - Error: 0.3209
# Iteration 3 - Error: 0.3227
# Iteration 4 - Error: 0.4087
# Iteration 5 - Error: 0.4130
# Iteration 6 - Error: 0.4566
# Iteration 7 - Error: 0.4033
# Iteration 8 - Error: 0.4388
# Iteration 9 - Error: 0.4809
# Iteration 10 - Error: 0.4989
# Iteration 11 - Error: 0.6276
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[48], line 14
#      10 base_estimator = M5Prime()
#      11 model = TrAdaBoostR2(base_estimator,
#      12                         n_estimators=30,
#      13                         lr=1)
# ---> 14 model.fit(X_source_train, y_source_train,
#      15             X_target_train, y_target_train)
#      16 preds = model.predict(X_target_test)
#      17 rmse = np.sqrt(mean_squared_error(
#      18     preds, y_target_test))
#
# File c:\Users\Dag Bjornberg\AI\transfertreeboost\env\Lib\site-packages\adapt\instance_based\_tradaboost.py:256, in TrAdaBoost.fit(self, X, y, Xt, yt, sample_weight_src, sample_weight_tgt, **fit_params)
#     251 self.sample_weights_src_.append(
#     252     np.copy(sample_weight_src))
#     253 self.sample_weights_tgt_.append(
#     254     np.copy(sample_weight_tgt))
# --> 256 sample_weight_src, sample_weight_tgt = self._boost(
#     257     iboost, Xs, ys, Xt, yt,
#     258     sample_weight_src, sample_weight_tgt,
#     259     **fit_params
#     260 )
#     262 if self.verbose >= 1:
#     263     print("Iteration %i - Error: %.4f"%
#     264           (iboost, self.estimator_errors_[-1]))
#
# File c:\Users\Dag Bjornberg\AI\transfertreeboost\env\Lib\site-packages\adapt\instance_based\_tradaboost.py:293, in TrAdaBoost._boost(self, iboost, Xs, ys, Xt, yt, sample_weight_src, sample_weight_tgt, **fit_params)
#     289 sample_weight = np.concatenate((sample_weight_src,
#     290                                 sample_weight_tgt))
#     292 # Need to rescale sample weight
# --> 293 estimator = self.fit_estimator(X, y,
#     294                                sample_weight=sample_weight/sample_weight.mean(),
#     295                                random_state=None,
#     296                                warm_start=False,
#     297                                **fit_params)
#     299 if not isinstance(self, TrAdaBoostR2) and isinstance(estimator, BaseEstimator):
#     300     if hasattr(estimator, "predict_proba"):
#
# File c:\Users\Dag Bjornberg\AI\transfertreeboost\env\Lib\site-packages\adapt\base.py:597, in BaseAdaptEstimator.fit_estimator(self, X, y, sample_weight, random_state, warm_start, **fit_params)
#     595     with warnings.catch_warnings():
#     596         warnings.simplefilter("ignore")
# --> 597         self.estimator_.fit(X, y,
#     598                             sample_weight=sample_weight,
#     599                             **fit_params)
#     600 else:
#     601     if sample_weight is None:
#
# File c:\Users\Dag Bjornberg\AI\transfertreeboost\env\Lib\site-packages\m5py\main.py:271, in M5Base.fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     266 nodes_to_samples = samples_to_nodes.tocsc()
#     268 # -- execute the pruning
#     269 # self.features_usage is a dict feature_idx -> nb times used, only
#     270 #   for used features.
# --> 271 self.features_usage = build_models_and_get_pruning_info(
#     272     self.tree_,
#     273     X,
#     274     y,
#     275     nodes_to_samples,
#     276     self.leaf_model,
#     277     self.node_models,
#     278     global_std_dev,
#     279     use_pruning=self.use_pruning,
#     280 )
#     282 # -- cleanup to compress inner structures: only keep non-pruned ones
#     283 self._cleanup_tree()
#
# File c:\Users\Dag Bjornberg\AI\transfertreeboost\env\Lib\site-packages\m5py\main.py:1273, in build_models_and_get_pruning_info(tree, X_train_all, y_train_all, nodes_to_samples, leaf_model, node_models, global_std_dev, use_pruning, node_id)
#    1268 # (1) prune left and right subtree and get some information
#    1269 features_l = build_models_and_get_pruning_info(
#    1270     tree, X_train_all, y_train_all, nodes_to_samples, leaf_model,
#    1271     node_models, global_std_dev, use_pruning, node_id=left_node
#    1272 )
# -> 1273 features_r = build_models_and_get_pruning_info(
#    1274     tree, X_train_all, y_train_all, nodes_to_samples, leaf_model,
#    1275     node_models, global_std_dev, use_pruning, node_id=right_node
#    1276 )
#    1278 # (2) select only the samples that reach this node
#    1279 X_this_node = X_train_all[samples_at_this_node, :]
#
# File c:\Users\Dag Bjornberg\AI\transfertreeboost\env\Lib\site-packages\m5py\main.py:1269, in build_models_and_get_pruning_info(tree, X_train_all, y_train_all, nodes_to_samples, leaf_model, node_models, global_std_dev, use_pruning, node_id)
#    1266 right_node = tree.children_right[node_id]
#    1268 # (1) prune left and right subtree and get some information
# -> 1269 features_l = build_models_and_get_pruning_info(
#    1270     tree, X_train_all, y_train_all, nodes_to_samples, leaf_model,
#    1271     node_models, global_std_dev, use_pruning, node_id=left_node
#    1272 )
#    1273 features_r = build_models_and_get_pruning_info(
#    1274     tree, X_train_all, y_train_all, nodes_to_samples, leaf_model,
#    1275     node_models, global_std_dev, use_pruning, node_id=right_node
#    1276 )
#    1278 # (2) select only the samples that reach this node
#
# File c:\Users\Dag Bjornberg\AI\transfertreeboost\env\Lib\site-packages\m5py\main.py:1269, in build_models_and_get_pruning_info(tree, X_train_all, y_train_all, nodes_to_samples, leaf_model, node_models, global_std_dev, use_pruning, node_id)
#    1266 right_node = tree.children_right[node_id]
#    1268 # (1) prune left and right subtree and get some information
# -> 1269 features_l = build_models_and_get_pruning_info(
#    1270     tree, X_train_all, y_train_all, nodes_to_samples, leaf_model,
#    1271     node_models, global_std_dev, use_pruning, node_id=left_node
#    1272 )
#    1273 features_r = build_models_and_get_pruning_info(
#    1274     tree, X_train_all, y_train_all, nodes_to_samples, leaf_model,
#    1275     node_models, global_std_dev, use_pruning, node_id=right_node
#    1276 )
#    1278 # (2) select only the samples that reach this node
#
#     [... skipping similar frames: build_models_and_get_pruning_info at line 1269 (2 times)]
#
# File c:\Users\Dag Bjornberg\AI\transfertreeboost\env\Lib\site-packages\m5py\main.py:1269, in build_models_and_get_pruning_info(tree, X_train_all, y_train_all, nodes_to_samples, leaf_model, node_models, global_std_dev, use_pruning, node_id)
#    1266 right_node = tree.children_right[node_id]
#    1268 # (1) prune left and right subtree and get some information
# -> 1269 features_l = build_models_and_get_pruning_info(
#    1270     tree, X_train_all, y_train_all, nodes_to_samples, leaf_model,
#    1271     node_models, global_std_dev, use_pruning, node_id=left_node
#    1272 )
#    1273 features_r = build_models_and_get_pruning_info(
#    1274     tree, X_train_all, y_train_all, nodes_to_samples, leaf_model,
#    1275     node_models, global_std_dev, use_pruning, node_id=right_node
#    1276 )
#    1278 # (2) select only the samples that reach this node
#
# File c:\Users\Dag Bjornberg\AI\transfertreeboost\env\Lib\site-packages\m5py\main.py:1273, in build_models_and_get_pruning_info(tree, X_train_all, y_train_all, nodes_to_samples, leaf_model, node_models, global_std_dev, use_pruning, node_id)
#    1268 # (1) prune left and right subtree and get some information
#    1269 features_l = build_models_and_get_pruning_info(
#    1270     tree, X_train_all, y_train_all, nodes_to_samples, leaf_model,
#    1271     node_models, global_std_dev, use_pruning, node_id=left_node
#    1272 )
# -> 1273 features_r = build_models_and_get_pruning_info(
#    1274     tree, X_train_all, y_train_all, nodes_to_samples, leaf_model,
#    1275     node_models, global_std_dev, use_pruning, node_id=right_node
#    1276 )
#    1278 # (2) select only the samples that reach this node
#    1279 X_this_node = X_train_all[samples_at_this_node, :]
#
# File c:\Users\Dag Bjornberg\AI\transfertreeboost\env\Lib\site-packages\m5py\main.py:1273, in build_models_and_get_pruning_info(tree, X_train_all, y_train_all, nodes_to_samples, leaf_model, node_models, global_std_dev, use_pruning, node_id)
#    1268 # (1) prune left and right subtree and get some information
#    1269 features_l = build_models_and_get_pruning_info(
#    1270     tree, X_train_all, y_train_all, nodes_to_samples, leaf_model,
#    1271     node_models, global_std_dev, use_pruning, node_id=left_node
#    1272 )
# -> 1273 features_r = build_models_and_get_pruning_info(
#    1274     tree, X_train_all, y_train_all, nodes_to_samples, leaf_model,
#    1275     node_models, global_std_dev, use_pruning, node_id=right_node
#    1276 )
#    1278 # (2) select only the samples that reach this node
#    1279 X_this_node = X_train_all[samples_at_this_node, :]
#
# File c:\Users\Dag Bjornberg\AI\transfertreeboost\env\Lib\site-packages\m5py\main.py:1306, in build_models_and_get_pruning_info(tree, X_train_all, y_train_all, nodes_to_samples, leaf_model, node_models, global_std_dev, use_pruning, node_id)
#    1303 selected_features = sorted(selected_features_dct.keys())
#    1305 X_train_this_node = X_this_node[:, selected_features]
# -> 1306 skmodel_this_node.fit(X_train_this_node, y_true_this_node)
#    1307 # -- predict and compute error
#    1308 y_pred_this_node = skmodel_this_node.predict(X_train_this_node)
#
# File c:\Users\Dag Bjornberg\AI\transfertreeboost\env\Lib\site-packages\sklearn\base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\Dag Bjornberg\AI\transfertreeboost\env\Lib\site-packages\sklearn\linear_model\_base.py:601, in LinearRegression.fit(self, X, y, sample_weight)
#     597 n_jobs_ = self.n_jobs
#     599 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 601 X, y = validate_data(
#     602     self,
#     603     X,
#     604     y,
#     605     accept_sparse=accept_sparse,
#     606     y_numeric=True,
#     607     multi_output=True,
#     608     force_writeable=True,
#     609 )
#     611 has_sw = sample_weight is not None
#     612 if has_sw:
#
# File c:\Users\Dag Bjornberg\AI\transfertreeboost\env\Lib\site-packages\sklearn\utils\validation.py:2961, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2959         y = check_array(y, input_name="y", **check_y_params)
#    2960     else:
# -> 2961         X, y = check_X_y(X, y, **check_params)
#    2962     out = X, y
#    2964 if not no_val_X and check_params.get("ensure_2d", True):
#
# File c:\Users\Dag Bjornberg\AI\transfertreeboost\env\Lib\site-packages\sklearn\utils\validation.py:1389, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1370 X = check_array(
#    1371     X,
#    1372     accept_sparse=accept_sparse,
#    (...)   1384     input_name="X",
#    1385 )
#    1387 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
# -> 1389 check_consistent_length(X, y)
#    1391 return X, y
#
# File c:\Users\Dag Bjornberg\AI\transfertreeboost\env\Lib\site-packages\sklearn\utils\validation.py:473, in check_consistent_length(*arrays)
#     455 """Check that all arrays have consistent first dimensions.
#     456
#     457 Checks whether all objects in arrays have the same shape or length.
#    (...)    469 >>> check_consistent_length(a, b)
#     470 """
#     472 lengths = [_num_samples(X) for X in arrays if X is not None]
# --> 473 uniques = np.unique(lengths)
#     474 if len(uniques) > 1:
#     475     raise ValueError(
#     476         "Found input variables with inconsistent numbers of samples: %r"
#     477         % [int(l) for l in lengths]
#     478     )
#
# File c:\Users\Dag Bjornberg\AI\transfertreeboost\env\Lib\site-packages\numpy\lib\_arraysetops_impl.py:286, in unique(ar, return_index, return_inverse, return_counts, axis, equal_nan)
#     284 ar = np.asanyarray(ar)
#     285 if axis is None:
# --> 286     ret = _unique1d(ar, return_index, return_inverse, return_counts,
#     287                     equal_nan=equal_nan, inverse_shape=ar.shape, axis=None)
#     288     return _unpack_tuple(ret)
#     290 # axis was specified and not None
#
# File c:\Users\Dag Bjornberg\AI\transfertreeboost\env\Lib\site-packages\numpy\lib\_arraysetops_impl.py:353, in _unique1d(ar, return_index, return_inverse, return_counts, equal_nan, inverse_shape, axis)
#     351     aux = ar[perm]
#     352 else:
# --> 353     ar.sort()
#     354     aux = ar
#     355 mask = np.empty(aux.shape, dtype=np.bool)
#
# KeyboardInterrupt:

# %%
# base_estimator = LinearTreeRegressor(
#     base_estimator=LinearRegression(),
#     max_depth=5,
#     min_samples_leaf=3)
base_estimator = M5Prime()
model = TwoStageTrAdaBoostR2(base_estimator,
                        n_estimators=30,
                        n_estimators_fs=30,
                        cv=10,
                        lr=1)
model.fit(X_source_train, y_source_train,
            X_target_train, y_target_train)
preds = model.predict(X_target_test)

rmse = np.sqrt(mean_squared_error(
    preds, y_target_test))
mae = mean_absolute_error(preds, y_target_test)
print((rmse / np.mean(y_target_test))*100)
# Out:
# Iteration 0 - Cross-validation score: 0.0995 (0.0338)
# Iteration 1 - Cross-validation score: 0.0958 (0.0349)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 11
#       5 base_estimator = M5Prime()
#       6 model = TwoStageTrAdaBoostR2(base_estimator,
#       7                         n_estimators=30,
#       8                         n_estimators_fs=30,
#       9                         cv=10,
#      10                         lr=1)
# ---> 11 model.fit(X_source_train, y_source_train,
#      12             X_target_train, y_target_train)
#      13 preds = model.predict(X_target_test)
#      15 rmse = np.sqrt(mean_squared_error(
#      16     preds, y_target_test))
#
# File c:\Users\Dag Bjornberg\AI\transfertreeboost\env\Lib\site-packages\adapt\instance_based\_tradaboost.py:857, in TwoStageTrAdaBoostR2.fit(self, X, y, Xt, yt, sample_weight_src, sample_weight_tgt, **fit_params)
#     853 if self.verbose >= 1:
#     854     print("Iteration %i - Cross-validation score: %.4f (%.4f)"%
#     855           (iboost, np.mean(cv_score), np.std(cv_score)))
# --> 857 sample_weight_src, sample_weight_tgt = self._boost(
#     858     iboost, Xs, ys, Xt, yt,
#     859     sample_weight_src, sample_weight_tgt,
#     860     **fit_params
#     861 )
#     863 self.estimator_errors_.append(cv_score.mean())
#     865 if sample_weight_src is None:
#
# File c:\Users\Dag Bjornberg\AI\transfertreeboost\env\Lib\site-packages\adapt\instance_based\_tradaboost.py:888, in TwoStageTrAdaBoostR2._boost(self, iboost, Xs, ys, Xt, yt, sample_weight_src, sample_weight_tgt, **fit_params)
#     885 if self.verbose > 1:
#     886     print("First Stages...")
# --> 888 estimator.fit(Xs, ys,
#     889               Xt=Xt, yt=yt,
#     890               sample_weight_src=sample_weight_src,
#     891               sample_weight_tgt=sample_weight_tgt,
#     892               **fit_params)
#     894 ys_pred = estimator.predict(Xs)
#     895 yt_pred = estimator.predict(Xt)
#
# File c:\Users\Dag Bjornberg\AI\transfertreeboost\env\Lib\site-packages\adapt\instance_based\_tradaboost.py:256, in TrAdaBoost.fit(self, X, y, Xt, yt, sample_weight_src, sample_weight_tgt, **fit_params)
#     251 self.sample_weights_src_.append(
#     252     np.copy(sample_weight_src))
#     253 self.sample_weights_tgt_.append(
#     254     np.copy(sample_weight_tgt))
# --> 256 sample_weight_src, sample_weight_tgt = self._boost(
#     257     iboost, Xs, ys, Xt, yt,
#     258     sample_weight_src, sample_weight_tgt,
#     259     **fit_params
#     260 )
#     262 if self.verbose >= 1:
#     263     print("Iteration %i - Error: %.4f"%
#     264           (iboost, self.estimator_errors_[-1]))
#
# File c:\Users\Dag Bjornberg\AI\transfertreeboost\env\Lib\site-packages\adapt\instance_based\_tradaboost.py:311, in TrAdaBoost._boost(self, iboost, Xs, ys, Xt, yt, sample_weight_src, sample_weight_tgt, **fit_params)
#     309 else:
#     310     ys_pred = estimator.predict(Xs)
# --> 311     yt_pred = estimator.predict(Xt)
#     313 if ys.ndim == 1:
#     314     ys = ys.reshape(-1, 1)
#
# File c:\Users\Dag Bjornberg\AI\transfertreeboost\env\Lib\site-packages\m5py\main.py:983, in M5Base.predict(self, X, check_input, smooth_predictions, smoothing_constant)
#     979 # Do not use the embedded tree (like in super): it has been pruned but
#     980 # still has constant nodes
#     981 # proba = self.tree_.predict(X)
#     982 if not smooth_predictions:
# --> 983     proba = predict_from_leaves_no_smoothing(self.tree_, self.node_models, X)
#     984 else:
#     985     proba = predict_from_leaves(self, X, smoothing=True, smoothing_constant=smoothing_constant)
#
# File c:\Users\Dag Bjornberg\AI\transfertreeboost\env\Lib\site-packages\m5py\main.py:1456, in predict_from_leaves_no_smoothing(tree, node_models, X)
#    1454 node_model = node_models[leaf_node_id]
#    1455 if isinstance(node_model, LinRegLeafModel):
# -> 1456     y_predicted[sample_indices] = np.ravel(node_model.predict(X[sample_indices, :]))
#    1457 else:
#    1458     # isinstance(node_model, ConstantLeafModel)
#    1459     y_predicted[sample_indices] = tree.value[leaf_node_id]
#
# File c:\Users\Dag Bjornberg\AI\transfertreeboost\env\Lib\site-packages\m5py\main.py:1123, in LinRegNodeModel.predict(self, X)
#    1119     # use the denormalize function on the internal model
#    1120     # TODO what if internal model is not able ?
#    1121     self.model.denormalize(x_scaler, y_scaler)
# -> 1123 def predict(self, X: np.ndarray):
#    1124     """Performs a prediction for X, only using the required features."""
#    1125     if len(self.features) < 1 and isinstance(self.model, LinearRegression):
#    1126         # unfortunately LinearRegression models do not like it when no
#    1127         # features are needed: their input validation requires at least 1.
#    1128         # so we do it ourselves.
#
# KeyboardInterrupt:

# %%
df = pd.DataFrame(columns = ['seed', 'method', 'rmse'])

for seed in range(89,99):
    data = pd.read_csv('datasets/stem_data.csv', index_col = [0])
    data_source = data[data['Species'] == 'Spruce']
    data_target = data[data['Species'] == 'Pine']
    print(f'source dataset size: {len(data_source)}, target dataset size: {len(data_target)}')

    data_temp, data_test = train_test_split(data_target, test_size=0.1, random_state=seed)
    data_train, data_val = train_test_split(data_temp, test_size=0.1, random_state=seed)

    X_source_train = np.array(data_source[predictor_columns])
    y_source_train = np.array(data_source[target_column]) #change this to "Dgv" to use diameter as source label!

    #Specific train and test set
    X_target_train = np.array(data_train[predictor_columns])
    y_target_train = np.array(data_train[target_column])

    X_target_val = np.array(data_val[predictor_columns])
    y_target_val = np.array(data_val[target_column])

    X_target_test = np.array(data_test[predictor_columns])
    y_target_test = np.array(data_test[target_column])

    fiter = MTransferTreeBoost()
    fiter.fit(X_target_train, y_target_train, X_source_train, y_source_train, val_x=X_target_val, val_y=y_target_val, early_stopping_rounds=5, show_curves = False)
    rmse = fiter.evaluate(X_target_test, y_target_test, metric = 'rmse')
    val_rmse = fiter.evaluate(X_target_val, y_target_val, metric = 'rmse')
    mae = fiter.evaluate(X_target_test, y_target_test, metric = 'mae')
    val_mae = fiter.evaluate(X_target_val, y_target_val, metric = 'mae')

    df.loc[len(df)] = [seed, 'MTransferTreeBoost', rmse]

    params = {
    'objective': 'reg:pseudohubererror',  # Regression with squared error
    'max_depth': 2,                   # Maximum depth of a tree
    'eta': 0.1,                       # Learning rate
    'eval_metric': 'rmse',           # RMSE as evaluation metric
    }
        
    bst = train_xgboost(X_target_train, y_target_train, X_target_val, y_target_val, boosting_rounds=300, params=params, early_stopping_rounds=5, show_curve=False)
    preds = test_xgboost(X_target_test, bst)
    val_preds = test_xgboost(X_target_val, bst)
    val_rmse = compute_rmse(val_preds, y_target_val)
    val_mae = compute_mae(val_preds, y_target_val)
    rmse = compute_rmse(preds, y_target_test)
    mae = compute_mae(preds, y_target_test)

    df.loc[len(df)] = [seed, 'XGBoost', rmse]


    base_estimator = M5Prime()
    model = TrAdaBoostR2(base_estimator,
                            n_estimators=30,
                            lr=1, verbose = False)
    model.fit(X_source_train, y_source_train,
                X_target_train, y_target_train)
    preds = model.predict(X_target_test)
    val_preds = model.predict(X_target_val)
    val_rmse = np.sqrt(
        mean_squared_error(val_preds, y_target_val))
    val_mae = mean_absolute_error(val_preds, y_target_val)
    rmse = np.sqrt(mean_squared_error(
        preds, y_target_test))
    mae = mean_absolute_error(preds, y_target_test)

    df.loc[len(df)] = [seed, 'TrAdaBoost.R2', rmse]
# Out:
# source dataset size: 113, target dataset size: 197
# source dataset size: 113, target dataset size: 197
# source dataset size: 113, target dataset size: 197
# source dataset size: 113, target dataset size: 197
# source dataset size: 113, target dataset size: 197
# source dataset size: 113, target dataset size: 197
# source dataset size: 113, target dataset size: 197
# source dataset size: 113, target dataset size: 197
# source dataset size: 113, target dataset size: 197
# source dataset size: 113, target dataset size: 197

# %%
import seaborn as sns
sns.boxplot(data = df, x = 'method', y = 'rmse')
# Out:
# <Axes: xlabel='method', ylabel='rmse'>

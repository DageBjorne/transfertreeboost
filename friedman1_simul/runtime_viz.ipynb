# %%
import pandas as pd
import seaborn as sns

# %%
dat = pd.read_csv('vizes/runtime_LS.csv')
sns.lineplot(data=dat, x='n_samples', y='time (s)')
# Out:
# <Axes: xlabel='n_samples', ylabel='time (s)'>

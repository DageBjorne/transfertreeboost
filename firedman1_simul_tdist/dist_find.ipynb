# %%
import numpy as np
import matplotlib.pyplot as plt
from friedman1 import *
noise = np.random.normal(size = 100000)
y = np.random.uniform(0.001, 1, size = 100000)
noise_ = noise / y
noise_t = np.random.standard_t(df=3, size = 100000)

# %%
plt.hist(noise, bins=100, density=True, alpha = 0.5)
plt.hist(noise_, bins = 100, alpha = 0.5, density=True)
plt.hist(noise_t, bins = 100, alpha = 0.5, density=True)
plt.legend(['norm', 'slash', 't'])
plt.xlim([-100,100])
plt.show()

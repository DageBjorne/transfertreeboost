# %%
import numpy as np
import matplotlib.pyplot as plt
from friedman1 import *
noise = np.random.normal(size = 100000)
y = np.random.uniform(0.001, 1, size = 100000)
noise_ = noise / y
noise_t = np.random.standard_t(df=2, size = 100000)

# %%
plt.figure(figsize = (20,8))
plt.hist(noise, bins=1000, alpha = 0.5)
plt.hist(noise_, bins = 10000, alpha = 0.5)
plt.hist(noise_t, bins = 10000, alpha = 0.5)
plt.legend(['norm', 'slash', 't'])
plt.xlim([-4,4])
plt.show()
